# %% [markdown]
# #### This workflow uses two available datasets (Texas Vegetation & Cemeteries) to answer the question: For Texas,  what is the type of vegetation at most cemeteries in?

# %%
from arcgis.gis import GIS
from arcgis.features import summarize_data

# add AGOL username and password
f = open('agol.csv')
username = str(f.readline())[:-1]
password = str(f.readline())
gis = GIS("https://www.arcgis.com", username, password)

# %%
veg_item_id = '7790083ace944f939367bd8f38678258'

veg_item = gis.content.get(veg_item_id)
veg_item
# Out:
# <Item title:"Texas Vegetation Type" type:Feature Layer Collection owner:mapsgis>

# %%
cemetery_item_id = '46892b74d36141949d932fc661caf3f9'

cemetery_item = gis.content.get(cemetery_item_id)
cemetery_item
# Out:
# <Item title:"Texas Cemeteries" type:Feature Layer Collection owner:TPP_GIS>

# %%
# access layers
veg_feature_lyr = veg_item.layers[0]
cemetery_feature_lyr = cemetery_item.layers[0]

# %%
# view names of fields
for field in veg_feature_lyr.properties.fields:
    print(field['name'])
print('#######################')
for field in cemetery_feature_lyr.properties.fields:
    print(field['name'])
# Out:
# FID
# AREA
# PERIMETER
# VEGPY03_
# VEGPY03_ID
# OBJECTID
# VEGCOVER
# CODENUM
# COLOR
# CODE
# C1
# SHAPE_AREA
# SHAPE_LEN
# Shape__Area
# Shape__Length
# #######################
# OBJECTID
# CEMETERY_NM
# DIST_NM
# CNTY_NM
# Zoom

# %%
# get the number of cemeteries in each polygon
cemetery_summary = summarize_data.aggregate_points(
    point_layer = cemetery_feature_lyr,
    polygon_layer = veg_feature_lyr,
    keep_boundaries_with_no_points = False,
)

# %%
cemetery_summary
# Out:
# {'aggregated_layer': <FeatureCollection>, 'group_summary': ''}

# %%
# need to access the feature collection, then query the data as a feature set
cemetery_aggregarte_fc = cemetery_summary['aggregated_layer']

cemetery_aggregarte_fset = cemetery_aggregarte_fc.query()

# %%
# view data as a pandas df
df = cemetery_aggregarte_fset.sdf
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 669 entries, 0 to 668
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   OBJECTID_1     669 non-null    int64
#  1   Point_Count    669 non-null    int64
#  2   AREA           669 non-null    float64
#  3   PERIMETER      669 non-null    float64
#  4   VEGPY03_       669 non-null    int64
#  5   VEGPY03_ID     669 non-null    int64
#  6   OBJECTID       669 non-null    int64
#  7   VEGCOVER       669 non-null    object
#  8   CODENUM        669 non-null    float64
#  9   COLOR          669 non-null    int64
#  10  CODE           669 non-null    object
#  11  C1             669 non-null    object
#  12  Shape__Area    669 non-null    float64
#  13  Shape__Length  669 non-null    float64
#  14  Shape_Length   669 non-null    float64
#  15  Shape_Area     669 non-null    float64
#  16  AnalysisArea   669 non-null    float64
#  17  SHAPE          669 non-null    geometry
# dtypes: float64(8), geometry(1), int64(6), object(3)
# memory usage: 94.2+ KB

# %%
# make df of groupby 
veg_group_df = df.groupby('VEGCOVER').count()['Point_Count'].reset_index()

# %%
# get top 15 types of vegcover 
df_15 = veg_group_df.sort_values('Point_Count', ascending=False).head(15)

# %%
# %matplotlib inline
df_15.plot('VEGCOVER','Point_Count', kind='barh')
